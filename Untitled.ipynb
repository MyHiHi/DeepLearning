# %%
import numpy as np 
p=np.random.randint(1,6,size=(3,2,3))
p1=np.random.randint(0,2,size=(3,2))
d=np.random.randint(0,2,size=(2))
c=p.mean(axis=1)
from matplotlib import pyplot as plt 
k=[.1,.2,.3]
for e,v in zip(k,c):
    plt.plot(v,label=f"e:{e}")
plt.legend()
plt.show()

# %%
# [xv if c else yv for (c,xv,yv) in zip(condition,x,y)]
condition=np.array([[True, False], [False, True]])
x=np.array([[1, 2], [3, 4]])
y=np.array([[5,6], [7,8]])
for (c,xv,yv) in zip(condition,x,y):
    print(c,xv,yv)
    for j in (c,xv,yv):
        print(j)
    print('-------')
# [xv if c else yv for (c,xv,yv) in zip(condition,x,y)]
np.where(p)
# Out:
# [ True False] [1 2] [5 6]
# [ True False]
# [1 2]
# [5 6]
# -------
# [False  True] [3 4] [7 8]
# [False  True]
# [3 4]
# [7 8]
# -------
# array([[1, 6],
#        [6, 4]])
