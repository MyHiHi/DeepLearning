# %% [markdown]
# > CART分类树采用**Gini指数**来进行特征选择
# > 完整的CART算法包括特征选择、决策树生成和决策树剪枝三个部分。
# ![微信图片_20200518122233.jpg](https://user-gold-cdn.xitu.io/2020/5/18/172260521433a2a1?w=1080&h=413&f=jpeg&s=53046)
# > CART是在**给定输入随机变量X条件下输出随机变量Y的条件概率分布**的学习方法。CART算法通过选择最优特征和特征值进行划分，将输入空间也就是特征空间划分为有限个单元，并在这些单元上确定预测的概率分布，也就是在输入给定的条件下输出条件概率分布。
# >
# > CART算法主要包括**回归树和分类树**两种。回归树用于**目标变量为连续型的建模任务，其特征选择准则用的是平方误差最小准则**。分类树用于**目标变量为离散型的的建模任务，其特征选择准则用的是基尼指数(Gini Index)**，这也有别于此前ID3的信息增益准则和C4.5的信息增益比准则。无论是回归树还是分类树，其算法核心都在于**递归地选择最优特征构建决策树**。
# >
# > 除了选择最优特征构建决策树之外，CART算法还包括另外一个重要的部分：**剪枝**。剪枝可以视为决策树算法的一种**正则化手段**，作为一种基于规则的非参数监督学习方法，决策树在训练很容易过拟合，导致最后生成的决策树泛化性能不高。
# > 另外，CART作为一种单模型，也是GBDT的基模型。当很多棵CART分类树或者回归树集成起来的时候，就形成了GBDT模型。
# >
# > Gini指数是针对概率分布而言的。假设在一个分类问题中有K个类，样本属于第k个类的概率$P_k$，则该样本概率分布的基尼指数为
# <center>$Gini(P)=\sum_{k=1}^{n}{(P_k*(1-P_k)}$ </center>
# [参考文章](https://mp.weixin.qq.com/s/jdUQIPM2AhAh7rzl1DPgIQ)

# %% [markdown]
# # 获取数据

# %%
import pandas as pd 
# df=pd.read_excel('sales_data.xls').iloc[:,1:]
# df[["天气","销量"]]
df=pd.read_excel('bank-data.xls').iloc[:,1:]
car_no=df[df.car=="YES"]
pep_no=df[(df.car=="YES") & (df.pep=="NO")]
len(pep_no)/len(car_no)
# Out:
# 0.5337837837837838

# %% [markdown]
# # 定义Gini指数的计算函数

# %%
def gini(ele):
    prob=[ele.count(i)/len(ele) for i in set(ele)]
    return sum(i*(1-i) for i in prob)
gini(df["pep"].tolist())
# Out:
# 0.49624444444444443

# %% [markdown]
# # 定义根据特征分割数据框的函数

# %%
def split_df(df,label):
    result={}
    for k in df[label].unique():
        result[k]=df[df[label]==k]
    return result
split_df(df,'pep')
# Out:
# {'YES':      age     sex      region    income married children  car save_act  \
#  0     48  FEMALE  INNER_CITY  17546.00      NO      YES   NO       NO
#  5     57  FEMALE        TOWN  37869.60     YES       NO   NO      YES
#  6     22    MALE       RURAL   8877.07      NO      YES   NO       NO
#  12    44  FEMALE        TOWN  15735.80     YES      YES   NO      YES
#  13    66  FEMALE        TOWN  55204.70     YES      YES  YES      YES
#  ..   ...     ...         ...       ...     ...      ...  ...      ...
#  587   43  FEMALE        TOWN  31273.80      NO      YES  YES      YES
#  591   40  FEMALE  INNER_CITY  31473.90      NO       NO   NO      YES
#  593   65    MALE    SUBURBAN  51417.00     YES       NO   NO      YES
#  597   31  FEMALE        TOWN  15976.30     YES      YES  YES      YES
#  599   38    MALE        TOWN  26671.60      NO      YES  YES       NO
#
#      current_act mortgage  pep
#  0            NO       NO  YES
#  5           YES       NO  YES
#  6           YES       NO  YES
#  12          YES      YES  YES
#  13          YES      YES  YES
#  ..          ...      ...  ...
#  587          NO       NO  YES
#  591         YES      YES  YES
#  593         YES       NO  YES
#  597          NO       NO  YES
#  599         YES      YES  YES
#
#  [274 rows x 11 columns],
#  'NO':      age     sex      region    income married children  car save_act  \
#  1     40    MALE        TOWN  30085.10     YES       NO  YES       NO
#  2     51  FEMALE  INNER_CITY  16575.40     YES      YES  YES      YES
#  3     23  FEMALE        TOWN  20375.40     YES       NO   NO       NO
#  4     57  FEMALE       RURAL  50576.30     YES      YES   NO      YES
#  7     58    MALE        TOWN  24946.60     YES      YES  YES      YES
#  ..   ...     ...         ...       ...     ...      ...  ...      ...
#  592   48    MALE        TOWN  20268.00     YES      YES   NO      YES
#  594   59  FEMALE       RURAL  30971.80     YES       NO  YES      YES
#  595   61  FEMALE  INNER_CITY  47025.00      NO       NO  YES      YES
#  596   30  FEMALE  INNER_CITY   9672.25     YES      YES  YES      YES
#  598   29    MALE  INNER_CITY  14711.80     YES      YES   NO      YES
#
#      current_act mortgage pep
#  1           YES      YES  NO
#  2           YES       NO  NO
#  3           YES       NO  NO
#  4            NO       NO  NO
#  7           YES       NO  NO
#  ..          ...      ...  ..
#  592         YES       NO  NO
#  594         YES      YES  NO
#  595         YES      YES  NO
#  596         YES       NO  NO
#  598          NO      YES  NO
#
#  [326 rows x 11 columns]}

# %% [markdown]
# # 根据Gini指数和条件Gini指数计算递归选择最优特征

# %%
def choose_best_col(df,label):
    cols=[c for c in df.columns if c!=label]
    min_gini,min_split_df,best_col=999,None,""
    for col in cols:
        gini_A=.0 
        splited_subset=split_df(df,col)
        for split_v,split_data in splited_subset.items():
            gini_K=gini(split_data[label].tolist())
            gini_A+=(len(split_data)/len(df))*gini_K
        if min_gini>gini_A:
            min_gini,min_split_df,best_col=gini_A,splited_subset,col 
    return min_gini,min_split_df,best_col
choose_best_col(df,"pep")
# Out:
# (0.0,
#  {17546.0:    age     sex      region   income married children car save_act current_act  \
#   0   48  FEMALE  INNER_CITY  17546.0      NO      YES  NO       NO          NO
#
#     mortgage  pep
#   0       NO  YES  ,
#   30085.1:    age   sex region   income married children  car save_act current_act  \
#   1   40  MALE   TOWN  30085.1     YES       NO  YES       NO         YES
#
#     mortgage pep
#   1      YES  NO  ,
#   16575.4:    age     sex      region   income married children  car save_act  \
#   2   51  FEMALE  INNER_CITY  16575.4     YES      YES  YES      YES
#
#     current_act mortgage pep
#   2         YES       NO  NO  ,
#   20375.4:    age     sex region   income married children car save_act current_act  \
#   3   23  FEMALE   TOWN  20375.4     YES       NO  NO       NO         YES
#
#     mortgage pep
#   3       NO  NO  ,
#   50576.3:    age     sex region   income married children car save_act current_act  \
#   4   57  FEMALE  RURAL  50576.3     YES      YES  NO      YES          NO
#
#     mortgage pep
#   4       NO  NO  ,
#   37869.6:    age     sex region   income married children car save_act current_act  \
#   5   57  FEMALE   TOWN  37869.6     YES       NO  NO      YES         YES
#
#     mortgage  pep
#   5       NO  YES  ,
#   8877.07:    age   sex region   income married children car save_act current_act  \
#   6   22  MALE  RURAL  8877.07      NO      YES  NO       NO         YES
#
#     mortgage  pep
#   6       NO  YES  ,
#   24946.6:    age   sex region   income married children  car save_act current_act  \
#   7   58  MALE   TOWN  24946.6     YES      YES  YES      YES         YES
#
#     mortgage pep
#   7       NO  NO  ,
#   25304.3:    age     sex    region   income married children  car save_act current_act  \
#   8   37  FEMALE  SUBURBAN  25304.3     YES       NO  YES       NO          NO
#
#     mortgage pep
#   8       NO  NO  ,
#   24212.1:    age   sex region   income married children  car save_act current_act  \
#   9   54  MALE   TOWN  24212.1     YES       NO  YES      YES         YES
#
#     mortgage pep
#   9       NO  NO  ,
#   59803.9:     age     sex region   income married children car save_act current_act  \
#   10   66  FEMALE   TOWN  59803.9     YES      YES  NO      YES         YES
#
#      mortgage pep
#   10       NO  NO  ,
#   26658.8:     age     sex      region   income married children  car save_act  \
#   11   52  FEMALE  INNER_CITY  26658.8      NO      YES  YES      YES
#
#      current_act mortgage pep
#   11         YES      YES  NO  ,
#   15735.8:     age     sex region   income married children car save_act current_act  \
#   12   44  FEMALE   TOWN  15735.8     YES      YES  NO      YES         YES
#
#      mortgage  pep
#   12      YES  YES  ,
#   55204.7:     age     sex region   income married children  car save_act current_act  \
#   13   66  FEMALE   TOWN  55204.7     YES      YES  YES      YES         YES
#
#      mortgage  pep
#   13      YES  YES  ,
#   19474.6:     age   sex region   income married children car save_act current_act  \
#   14   36  MALE  RURAL  19474.6     YES      YES  NO      YES         YES
#
#      mortgage pep
#   14      YES  NO  ,
#   22342.1:     age     sex      region   income married children  car save_act  \
#   15   38  FEMALE  INNER_CITY  22342.1     YES      YES  YES      YES
#
#      current_act mortgage pep
#   15         YES      YES  NO  ,
#   17729.8:     age     sex region   income married children car save_act current_act  \
#   16   37  FEMALE   TOWN  17729.8     YES       NO  NO       NO          NO
#
#      mortgage pep
#   16      YES  NO  ,
#   41016.0:     age     sex    region   income married children car save_act current_act  \
#   17   46  FEMALE  SUBURBAN  41016.0     YES      YES  NO      YES          NO
#
#      mortgage pep
#   17      YES  NO  ,
#   26909.2:     age     sex      region   income married children car save_act  \
#   18   62  FEMALE  INNER_CITY  26909.2     YES      YES  NO      YES
#
#      current_act mortgage  pep
#   18          NO       NO  YES  ,
#   22522.8:     age   sex region   income married children  car save_act current_act  \
#   19   31  MALE   TOWN  22522.8     YES      YES  YES      YES         YES
#
#      mortgage pep
#   19       NO  NO  ,
#   57880.7:     age   sex      region   income married children car save_act current_act  \
#   20   61  MALE  INNER_CITY  57880.7     YES       NO  NO      YES          NO
#
#      mortgage  pep
#   20       NO  YES  ,
#   16497.3:     age   sex region   income married children car save_act current_act  \
#   21   50  MALE   TOWN  16497.3     YES       NO  NO      YES         YES
#
#      mortgage pep
#   21       NO  NO  ,
#   38446.6:     age   sex      region   income married children car save_act current_act  \
#   22   54  MALE  INNER_CITY  38446.6     YES      YES  NO      YES         YES
#
#      mortgage pep
#   22       NO  NO  ,
#   15538.8:     age     sex region   income married children  car save_act current_act  \
#   23   27  FEMALE   TOWN  15538.8      NO      YES  YES      YES         YES
#
#      mortgage pep
#   23      YES  NO  ,
#   12640.3:     age   sex      region   income married children  car save_act current_act  \
#   24   22  MALE  INNER_CITY  12640.3      NO       NO  YES      YES         YES
#
#      mortgage pep
#   24       NO  NO  ,
#   41034.0:     age   sex      region   income married children  car save_act current_act  \
#   25   56  MALE  INNER_CITY  41034.0     YES      YES  YES      YES         YES
#
#      mortgage pep
#   25      YES  NO  ,
#   20809.7:     age   sex      region   income married children car save_act current_act  \
#   26   45  MALE  INNER_CITY  20809.7     YES      YES  NO      YES         YES
#
#      mortgage pep
#   26      YES  NO  ,
#   20114.0:     age     sex region   income married children car save_act current_act  \
#   27   39  FEMALE   TOWN  20114.0     YES      YES  NO       NO         YES
#
#      mortgage  pep
#   27       NO  YES  ,
#   29359.1:     age     sex      region   income married children  car save_act  \
#   28   39  FEMALE  INNER_CITY  29359.1      NO       NO  YES       NO
#
#      current_act mortgage pep
#   28         YES      YES  NO  ,
#   24270.1:     age   sex region   income married children car save_act current_act  \
#   29   61  MALE  RURAL  24270.1     YES      YES  NO       NO         YES
#
#      mortgage  pep
#   29       NO  YES  ,
#   22942.9:     age     sex region   income married children car save_act current_act  \
#   30   61  FEMALE  RURAL  22942.9     YES       NO  NO      YES         YES
#
#      mortgage pep
#   30       NO  NO  ,
#   16325.8:     age     sex region   income married children car save_act current_act  \
#   31   20  FEMALE   TOWN  16325.8     YES       NO  NO      YES          NO
#
#      mortgage pep
#   31       NO  NO  ,
#   23443.2:     age   sex    region   income married children  car save_act current_act  \
#   32   45  MALE  SUBURBAN  23443.2     YES      YES  YES      YES         YES
#
#      mortgage  pep
#   32       NO  YES  ,
#   29921.3:     age     sex      region   income married children  car save_act  \
#   33   33  FEMALE  INNER_CITY  29921.3      NO       NO  YES      YES
#
#      current_act mortgage pep
#   33          NO       NO  NO  ,
#   37521.9:     age   sex    region   income married children car save_act current_act  \
#   34   43  MALE  SUBURBAN  37521.9      NO      YES  NO      YES         YES
#
#      mortgage  pep
#   34       NO  YES  ,
#   19868.0:     age     sex      region   income married children car save_act  \
#   35   27  FEMALE  INNER_CITY  19868.0     YES       NO  NO      YES
#
#      current_act mortgage pep
#   35         YES       NO  NO  ,
#   10953.0:     age   sex region   income married children  car save_act current_act  \
#   36   19  MALE  RURAL  10953.0     YES       NO  YES      YES         YES
#
#      mortgage pep
#   36       NO  NO  ,
#   13381.0:     age     sex region   income married children  car save_act current_act  \
#   37   36  FEMALE  RURAL  13381.0      NO      YES  YES       NO         YES
#
#      mortgage  pep
#   37       NO  YES  ,
#   18504.3:     age     sex region   income married children  car save_act current_act  \
#   38   43  FEMALE   TOWN  18504.3     YES      YES  YES      YES         YES
#
#      mortgage pep
#   38       NO  NO  ,
#   25391.5:     age     sex    region   income married children car save_act current_act  \
#   39   66  FEMALE  SUBURBAN  25391.5      NO       NO  NO       NO         YES
#
#      mortgage pep
#   39       NO  NO  ,
#   26774.2:     age   sex region   income married children car save_act current_act  \
#   40   55  MALE   TOWN  26774.2     YES      YES  NO       NO         YES
#
#      mortgage  pep
#   40      YES  YES  ,
#   26952.6:     age     sex      region   income married children  car save_act  \
#   41   47  FEMALE  INNER_CITY  26952.6     YES      YES  YES       NO
#
#      current_act mortgage pep
#   41         YES       NO  NO  ,
#   55716.5:     age   sex region   income married children  car save_act current_act  \
#   42   67  MALE   TOWN  55716.5      NO       NO  YES      YES          NO
#
#      mortgage  pep
#   42       NO  YES  ,
#   27571.5:     age     sex region   income married children  car save_act current_act  \
#   43   32  FEMALE   TOWN  27571.5     YES      YES  YES       NO         YES
#
#      mortgage pep
#   43      YES  NO  ,
#   13740.0:     age   sex      region   income married children  car save_act current_act  \
#   44   20  MALE  INNER_CITY  13740.0      NO       NO  YES      YES         YES
#
#      mortgage pep
#   44      YES  NO  ,
#   52670.6:     age   sex      region   income married children car save_act current_act  \
#   45   64  MALE  INNER_CITY  52670.6     YES       NO  NO      YES         YES
#
#      mortgage  pep
#   45      YES  YES  ,
#   13283.9:     age     sex      region   income married children  car save_act  \
#   46   50  FEMALE  INNER_CITY  13283.9      NO      YES  YES      YES
#
#      current_act mortgage  pep
#   46         YES       NO  YES  ,
#   13106.6:     age   sex      region   income married children car save_act current_act  \
#   47   29  MALE  INNER_CITY  13106.6      NO       NO  NO      YES         YES
#
#      mortgage  pep
#   47      YES  YES  ,
#   39547.8:     age   sex      region   income married children  car save_act current_act  \
#   48   52  MALE  INNER_CITY  39547.8      NO       NO  YES       NO         YES
#
#      mortgage  pep
#   48       NO  YES  ,
#   17867.3:     age     sex region   income married children  car save_act current_act  \
#   49   47  FEMALE  RURAL  17867.3     YES       NO  YES      YES          NO
#
#      mortgage pep
#   49       NO  NO  ,
#   14309.7:     age   sex region   income married children  car save_act current_act  \
#   50   24  MALE   TOWN  14309.7      NO       NO  YES      YES          NO
#
#      mortgage pep
#   50       NO  NO  ,
#   23894.8:     age   sex region   income married children car save_act current_act  \
#   51   36  MALE   TOWN  23894.8     YES      YES  NO       NO          NO
#
#      mortgage pep
#   51       NO  NO  ,
#   16259.7:     age   sex region   income married children car save_act current_act  \
#   52   43  MALE   TOWN  16259.7     YES      YES  NO      YES         YES
#
#      mortgage  pep
#   52       NO  YES  ,
#   29794.1:     age   sex    region   income married children car save_act current_act  \
#   53   48  MALE  SUBURBAN  29794.1      NO      YES  NO      YES         YES
#
#      mortgage  pep
#   53       NO  YES  ,
#   56842.5:     age   sex region   income married children car save_act current_act  \
#   54   63  MALE   TOWN  56842.5     YES      YES  NO      YES         YES
#
#      mortgage pep
#   54      YES  NO  ,
#   47835.8:     age     sex region   income married children car save_act current_act  \
#   55   52  FEMALE  RURAL  47835.8      NO       NO  NO      YES          NO
#
#      mortgage  pep
#   55       NO  YES  ,
#   24977.5:     age     sex      region   income married children car save_act  \
#   56   58  FEMALE  INNER_CITY  24977.5      NO      YES  NO       NO
#
#      current_act mortgage  pep
#   56         YES       NO  YES  ,
#   23124.9:     age   sex      region   income married children car save_act current_act  \
#   57   28  MALE  INNER_CITY  23124.9     YES      YES  NO      YES         YES
#
#      mortgage  pep
#   57       NO  YES  ,
#   15143.8:     age     sex      region   income married children car save_act  \
#   58   29  FEMALE  INNER_CITY  15143.8     YES      YES  NO       NO
#
#      current_act mortgage pep
#   58         YES       NO  NO  ,
#   25334.3:     age   sex      region   income married children  car save_act current_act  \
#   59   34  MALE  INNER_CITY  25334.3      NO      YES  YES      YES         YES
#
#      mortgage  pep
#   59      YES  YES  ,
#   24763.3:     age     sex      region   income married children car save_act  \
#   60   42  FEMALE  INNER_CITY  24763.3     YES      YES  NO      YES
#
#      current_act mortgage  pep
#   60         YES      YES  YES  ,
#   36589.0:     age     sex      region   income married children  car save_act  \
#   61   65  FEMALE  INNER_CITY  36589.0      NO      YES  YES       NO
#
#      current_act mortgage  pep
#   61         YES       NO  YES  ,
#   27022.6:     age   sex      region   income married children car save_act current_act  \
#   62   47  MALE  INNER_CITY  27022.6     YES       NO  NO      YES         YES
#
#      mortgage pep
#   62       NO  NO  ,
#   11700.4:     age   sex      region   income married children car save_act current_act  \
#   63   20  MALE  INNER_CITY  11700.4     YES      YES  NO      YES          NO
#
#      mortgage pep
#   63       NO  NO  ,
#   5014.21:     age   sex region   income married children  car save_act current_act  \
#   64   21  MALE   TOWN  5014.21      NO      YES  YES      YES         YES
#
#      mortgage pep
#   64      YES  NO  ,
#   17390.1:     age   sex      region   income married children car save_act current_act  \
#   65   42  MALE  INNER_CITY  17390.1     YES      YES  NO      YES         YES
#
#      mortgage pep
#   65       NO  NO  ,
#   10861.0:     age   sex region   income married children car save_act current_act  \
#   66   19  MALE   TOWN  10861.0      NO       NO  NO      YES         YES
#
#      mortgage pep
#   66       NO  NO  ,
#   34892.9:     age     sex region   income married children car save_act current_act  \
#   67   41  FEMALE   TOWN  34892.9      NO      YES  NO      YES         YES
#
#      mortgage pep
#   67      YES  NO  ,
#   19403.1:     age   sex region   income married children car save_act current_act  \
#   68   30  MALE   TOWN  19403.1      NO       NO  NO      YES         YES
#
#      mortgage pep
#   68       NO  NO  ,
#   10441.9:     age     sex region   income married children car save_act current_act  \
#   69   31  FEMALE  RURAL  10441.9     YES       NO  NO       NO         YES
#
#      mortgage  pep
#   69       NO  YES  ,
#   14064.9:     age   sex      region   income married children  car save_act current_act  \
#   70   25  MALE  INNER_CITY  14064.9     YES       NO  YES      YES         YES
#
#      mortgage pep
#   70       NO  NO  ,
#   8062.73:     age   sex      region   income married children car save_act current_act  \
#   71   21  MALE  INNER_CITY  8062.73      NO      YES  NO       NO         YES
#
#      mortgage  pep
#   71       NO  YES  ,
#   31982.0:     age   sex      region   income married children  car save_act current_act  \
#   72   36  MALE  INNER_CITY  31982.0     YES       NO  YES      YES         YES
#
#      mortgage  pep
#   72      YES  YES  ,
#   23197.5:     age     sex      region   income married children car save_act  \
#   73   58  FEMALE  INNER_CITY  23197.5     YES       NO  NO      YES
#
#      current_act mortgage pep
#   73          NO      YES  NO  ,
#   52674.0:     age     sex      region   income married children  car save_act  \
#   74   64  FEMALE  INNER_CITY  52674.0      NO       NO  YES      YES
#
#      current_act mortgage  pep
#   74         YES       NO  YES  ,
#   35610.5:     age     sex region   income married children  car save_act current_act  \
#   75   59  FEMALE  RURAL  35610.5      NO       NO  YES       NO          NO
#
#      mortgage  pep
#   75       NO  YES  ,
#   26948.0:     age     sex region   income married children car save_act current_act  \
#   76   45  FEMALE   TOWN  26948.0      NO      YES  NO      YES         YES
#
#      mortgage pep
#   76      YES  NO  ,
#   49456.7:     age   sex      region   income married children  car save_act current_act  \
#   77   61  MALE  INNER_CITY  49456.7     YES      YES  YES      YES         YES
#
#      mortgage  pep
#   77      YES  YES  ,
#   14724.5:     age     sex      region   income married children  car save_act  \
#   78   30  FEMALE  INNER_CITY  14724.5     YES      YES  YES       NO
#
#      current_act mortgage pep
#   78         YES       NO  NO  ,
#   34524.9:     age     sex region   income married children  car save_act current_act  \
#   79   58  FEMALE   TOWN  34524.9     YES       NO  YES      YES          NO
#
#      mortgage  pep
#   79       NO  YES  ,
#   22052.1:     age     sex region   income married children car save_act current_act  \
#   80   50  FEMALE   TOWN  22052.1      NO       NO  NO      YES         YES
#
#      mortgage  pep
#   80       NO  YES  ,
#   27808.1:     age   sex      region   income married children car save_act current_act  \
#   81   30  MALE  INNER_CITY  27808.1      NO       NO  NO       NO         YES
#
#      mortgage pep
#   81       NO  NO  ,
#   12591.4:     age     sex      region   income married children car save_act  \
#   82   29  FEMALE  INNER_CITY  12591.4     YES      YES  NO      YES
#
#      current_act mortgage pep
#   82         YES       NO  NO  ,
#   16394.4:     age   sex      region   income married children car save_act current_act  \
#   83   35  MALE  INNER_CITY  16394.4     YES      YES  NO      YES         YES
#
#      mortgage  pep
#   83       NO  YES  ,
#   24026.1:     age   sex      region   income married children car save_act current_act  \
#   84   62  MALE  INNER_CITY  24026.1     YES      YES  NO       NO         YES
#
#      mortgage  pep
#   84      YES  YES  ,
#   31683.1:     age   sex      region   income married children  car save_act current_act  \
#   85   36  MALE  INNER_CITY  31683.1     YES      YES  YES      YES         YES
#
#      mortgage  pep
#   85       NO  YES  ,
#   15525.0:     age     sex      region   income married children car save_act  \
#   86   25  FEMALE  INNER_CITY  15525.0     YES      YES  NO      YES
#
#      current_act mortgage pep
#   86         YES       NO  NO  ,
#   22562.2:     age     sex region   income married children  car save_act current_act  \
#   87   66  FEMALE   TOWN  22562.2      NO      YES  YES      YES         YES
#
#      mortgage pep
#   87      YES  NO  ,
#   15848.7:     age   sex    region   income married children  car save_act current_act  \
#   88   30  MALE  SUBURBAN  15848.7     YES      YES  YES      YES          NO
#
#      mortgage pep
#   88      YES  NO  ,
#   31095.6:     age     sex      region   income married children car save_act  \
#   89   54  FEMALE  INNER_CITY  31095.6     YES       NO  NO       NO
#
#      current_act mortgage  pep
#   89         YES       NO  YES  ,
#   24814.5:     age   sex region   income married children  car save_act current_act  \
#   90   37  MALE   TOWN  24814.5     YES      YES  YES       NO         YES
#
#      mortgage  pep
#   90      YES  YES  ,
#   25429.3:     age     sex      region   income married children car save_act  \
#   91   28  FEMALE  INNER_CITY  25429.3      NO       NO  NO      YES
#
#      current_act mortgage pep
#   91         YES      YES  NO  ,
#   34866.5:     age     sex region   income married children car save_act current_act  \
#   92   53  FEMALE  RURAL  34866.5      NO      YES  NO       NO         YES
#
#      mortgage  pep
#   92       NO  YES  ,
#   42579.1:     age   sex      region   income married children  car save_act current_act  \
#   93   61  MALE  INNER_CITY  42579.1     YES       NO  YES      YES         YES
#
#      mortgage pep
#   93       NO  NO  ,
#   41127.4:     age     sex      region   income married children  car save_act  \
#   94   61  FEMALE  INNER_CITY  41127.4     YES      YES  YES      YES
#
#      current_act mortgage pep
#   94          NO       NO  NO  ,
#   9990.11:     age     sex      region   income married children car save_act  \
#   95   18  FEMALE  INNER_CITY  9990.11     YES      YES  NO      YES
#
#      current_act mortgage pep
#   95         YES       NO  NO  ,
#   7948.62:     age   sex      region   income married children car save_act current_act  \
#   96   22  MALE  INNER_CITY  7948.62     YES      YES  NO       NO          NO
#
#      mortgage pep
#   96      YES  NO  ,
#   30870.8:     age   sex region   income married children  car save_act current_act  \
#   97   34  MALE   TOWN  30870.8     YES       NO  YES      YES         YES
#
#      mortgage  pep
#   97      YES  YES  ,
#   12125.8:     age     sex      region   income married children car save_act  \
#   98   35  FEMALE  INNER_CITY  12125.8      NO       NO  NO      YES
#
#      current_act mortgage pep
#   98         YES       NO  NO  ,
#   15348.9:     age     sex region   income married children  car save_act current_act  \
#   99   18  FEMALE  RURAL  15348.9     YES      YES  YES       NO         YES
#
#      mortgage pep
#   99       NO  NO  ,
#   26707.9:      age   sex      region   income married children car save_act current_act  \
#   100   54  MALE  INNER_CITY  26707.9     YES      YES  NO      YES         YES
#
#       mortgage  pep
#   100      YES  YES  ,
#   11604.4:      age     sex      region   income married children  car save_act  \
#   101   27  FEMALE  INNER_CITY  11604.4     YES       NO  YES      YES
#
#       current_act mortgage pep
#   101         YES       NO  NO  ,
#   15499.9:      age   sex      region   income married children  car save_act  \
#   102   42  MALE  INNER_CITY  15499.9     YES      YES  YES       NO
#
#       current_act mortgage  pep
#   102         YES      YES  YES  ,
#   33088.5:      age   sex region   income married children car save_act current_act  \
#   103   43  MALE   TOWN  33088.5      NO      YES  NO      YES         YES
#
#       mortgage pep
#   103      YES  NO  ,
#   34513.6:      age     sex      region   income married children car save_act  \
#   104   64  FEMALE  INNER_CITY  34513.6     YES      YES  NO      YES
#
#       current_act mortgage  pep
#   104         YES       NO  YES  ,
#   32395.5:      age   sex region   income married children  car save_act current_act  \
#   105   43  MALE   TOWN  32395.5     YES       NO  YES      YES         YES
#
#       mortgage pep
#   105       NO  NO  ,
#   46633.0:      age   sex region   income married children  car save_act current_act  \
#   106   49  MALE  RURAL  46633.0     YES      YES  YES      YES          NO
#
#       mortgage pep
#   106       NO  NO  ,
#   13039.9:      age   sex      region   income married children car save_act current_act  \
#   107   23  MALE  INNER_CITY  13039.9     YES      YES  NO       NO         YES
#
#       mortgage pep
#   107       NO  NO  ,
#   12681.9:      age   sex      region   income married children car save_act current_act  \
#   108   23  MALE  INNER_CITY  12681.9      NO      YES  NO      YES         YES
#
#       mortgage  pep
#   108       NO  YES  ,
#   24031.5:      age     sex      region   income married children  car save_act  \
#   109   30  FEMALE  INNER_CITY  24031.5     YES       NO  YES      YES
#
#       current_act mortgage pep
#   109         YES      YES  NO  ,
#   37330.5:      age   sex region   income married children car save_act current_act  \
#   110   36  MALE   TOWN  37330.5      NO       NO  NO      YES         YES
#
#       mortgage  pep
#   110       NO  YES  ,
#   25333.2:      age   sex      region   income married children  car save_act  \
#   111   34  MALE  INNER_CITY  25333.2     YES       NO  YES       NO
#
#       current_act mortgage pep
#   111          NO      YES  NO  ,
#   37094.2:      age     sex      region   income married children  car save_act  \
#   112   51  FEMALE  INNER_CITY  37094.2     YES      YES  YES       NO
#
#       current_act mortgage pep
#   112         YES       NO  NO  ,
#   33630.6:      age   sex region   income married children  car save_act current_act  \
#   113   36  MALE   TOWN  33630.6      NO       NO  YES      YES         YES
#
#       mortgage  pep
#   113       NO  YES  ,
#   43228.2:      age   sex      region   income married children  car save_act  \
#   114   56  MALE  INNER_CITY  43228.2     YES      YES  YES      YES
#
#       current_act mortgage  pep
#   114         YES       NO  YES  ,
#   47796.8:      age     sex      region   income married children car save_act  \
#   115   54  FEMALE  INNER_CITY  47796.8     YES      YES  NO      YES
#
#       current_act mortgage pep
#   115         YES       NO  NO  ,
#   21730.3:      age     sex region   income married children car save_act current_act  \
#   116   56  FEMALE   TOWN  21730.3     YES       NO  NO      YES          NO
#
#       mortgage pep
#   116       NO  NO  ,
#   10044.1:      age   sex      region   income married children car save_act current_act  \
#   117   26  MALE  INNER_CITY  10044.1     YES       NO  NO      YES         YES
#
#       mortgage pep
#   117      YES  NO  ,
#   17270.1:      age   sex region   income married children  car save_act current_act  \
#   118   39  MALE   TOWN  17270.1      NO      YES  YES       NO          NO
#
#       mortgage  pep
#   118       NO  YES  ,
#   45765.0:      age     sex region   income married children  car save_act current_act  \
#   119   64  FEMALE  RURAL  45765.0     YES       NO  YES      YES         YES
#
#       mortgage  pep
#   119       NO  YES  ,
#   29525.5:      age   sex region   income married children car save_act current_act  \
#   120   46  MALE  RURAL  29525.5      NO       NO  NO      YES          NO
#
#       mortgage pep
#   120      YES  NO  ,
#   54863.8:      age     sex region   income married children  car save_act current_act  \
#   121   62  FEMALE  RURAL  54863.8     YES      YES  YES      YES         YES
#
#       mortgage  pep
#   121       NO  YES  ,
#   20799.0:      age     sex region   income married children car save_act current_act  \
#   122   36  FEMALE   TOWN  20799.0     YES      YES  NO      YES          NO
#
#       mortgage  pep
#   122      YES  YES  ,
#   33028.3:      age     sex region   income married children car save_act current_act  \
#   123   35  FEMALE  RURAL  33028.3      NO      YES  NO      YES         YES
#
#       mortgage  pep
#   123       NO  YES  ,
#   45031.9:      age   sex region   income married children  car save_act current_act  \
#   124   47  MALE  RURAL  45031.9      NO       NO  YES      YES          NO
#
#       mortgage  pep
#   124       NO  YES  ,
#   39010.8:      age   sex      region   income married children car save_act current_act  \
#   125   47  MALE  INNER_CITY  39010.8     YES       NO  NO       NO         YES
#
#       mortgage  pep
#   125       NO  YES  ,
#   25257.7:      age     sex region   income married children  car save_act current_act  \
#   126   37  FEMALE   TOWN  25257.7     YES      YES  YES      YES         YES
#
#       mortgage pep
#   126       NO  NO  ,
#   42603.9:      age     sex      region   income married children car save_act  \
#   127   48  FEMALE  INNER_CITY  42603.9     YES      YES  NO      YES
#
#       current_act mortgage pep
#   127         YES       NO  NO  ,
#   14092.7:      age   sex region   income married children  car save_act current_act  \
#   128   41  MALE   TOWN  14092.7     YES       NO  YES      YES         YES
#
#       mortgage pep
#   128       NO  NO  ,
#   21350.3:      age     sex region   income married children  car save_act current_act  \
#   129   27  FEMALE  RURAL  21350.3      NO      YES  YES      YES         YES
#
#       mortgage  pep
#   129       NO  YES  ,
#   23246.4:      age   sex      region   income married children car save_act current_act  \
#   130   43  MALE  INNER_CITY  23246.4      NO       NO  NO       NO         YES
#
#       mortgage pep
#   130       NO  NO  ,
#   41609.5:      age   sex region   income married children car save_act current_act  \
#   131   61  MALE  RURAL  41609.5     YES       NO  NO      YES         YES
#
#       mortgage pep
#   131      YES  NO  ,
#   16716.1:      age     sex    region   income married children  car save_act  \
#   132   52  FEMALE  SUBURBAN  16716.1      NO       NO  YES      YES
#
#       current_act mortgage pep
#   132         YES       NO  NO  ,
#   36436.4:      age     sex    region   income married children  car save_act  \
#   133   64  FEMALE  SUBURBAN  36436.4     YES      YES  YES       NO
#
#       current_act mortgage pep
#   133         YES       NO  NO  ,
#   59503.8:      age     sex region   income married children  car save_act current_act  \
#   134   66  FEMALE   TOWN  59503.8     YES       NO  YES      YES         YES
#
#       mortgage  pep
#   134      YES  YES  ,
#   31334.8:      age     sex region   income married children  car save_act current_act  \
#   135   53  FEMALE   TOWN  31334.8     YES      YES  YES      YES         YES
#
#       mortgage  pep
#   135       NO  YES  ,
#   14048.9:      age     sex      region   income married children  car save_act  \
#   136   20  FEMALE  INNER_CITY  14048.9     YES       NO  YES       NO
#
#       current_act mortgage pep
#   136         YES      YES  NO  ,
#   39205.3:      age     sex      region   income married children car save_act  \
#   137   57  FEMALE  INNER_CITY  39205.3      NO      YES  NO      YES
#
#       current_act mortgage  pep
#   137         YES       NO  YES  ,
#   42173.9:      age     sex region   income married children car save_act current_act  \
#   138   65  FEMALE  RURAL  42173.9     YES      YES  NO      YES         YES
#
#       mortgage pep
#   138       NO  NO  ,
#   55263.0:      age     sex      region   income married children car save_act  \
#   139   64  FEMALE  INNER_CITY  55263.0      NO      YES  NO      YES
#
#       current_act mortgage  pep
#   139         YES       NO  YES  ,
#   37095.2:      age   sex      region   income married children car save_act current_act  \
#   140   52  MALE  INNER_CITY  37095.2     YES       NO  NO      YES         YES
#
#       mortgage pep
#   140       NO  NO  ,
#   22791.4:      age     sex      region   income married children car save_act  \
#   141   47  FEMALE  INNER_CITY  22791.4     YES      YES  NO       NO
#
#       current_act mortgage pep
#   141         YES       NO  NO  ,
#   17240.6:      age     sex region   income married children  car save_act current_act  \
#   142   28  FEMALE   TOWN  17240.6     YES      YES  YES       NO          NO
#
#       mortgage pep
#   142      YES  NO  ,
#   48974.8:      age   sex region   income married children  car save_act current_act  \
#   143   64  MALE   TOWN  48974.8     YES      YES  YES      YES         YES
#
#       mortgage pep
#   143      YES  NO  ,
#   18923.0:      age   sex      region   income married children car save_act current_act  \
#   144   25  MALE  INNER_CITY  18923.0     YES      YES  NO      YES         YES
#
#       mortgage  pep
#   144       NO  YES  ,
#   51204.2:      age   sex    region   income married children car save_act current_act  \
#   145   58  MALE  SUBURBAN  51204.2     YES      YES  NO      YES          NO
#
#       mortgage  pep
#   145      YES  YES  ,
#   20236.2:      age   sex region   income married children  car save_act current_act  \
#   146   34  MALE   TOWN  20236.2     YES       NO  YES       NO         YES
#
#       mortgage pep
#   146       NO  NO  ,
#   18860.3:      age     sex      region   income married children car save_act  \
#   147   20  FEMALE  INNER_CITY  18860.3      NO       NO  NO      YES
#
#       current_act mortgage pep
#   147         YES       NO  NO  ,
#   25732.5:      age   sex region   income married children  car save_act current_act  \
#   148   63  MALE  RURAL  25732.5     YES      YES  YES      YES          NO
#
#       mortgage pep
#   148       NO  NO  ,
#   28240.4:      age     sex    region   income married children  car save_act  \
#   149   30  FEMALE  SUBURBAN  28240.4     YES       NO  YES      YES
#
#       current_act mortgage pep
#   149         YES       NO  NO  ,
#   28193.6:      age   sex region   income married children  car save_act current_act  \
#   150   53  MALE  RURAL  28193.6     YES      YES  YES      YES         YES
#
#       mortgage  pep
#   150       NO  YES  ,
#   36432.8:      age   sex region   income married children  car save_act current_act  \
#   151   43  MALE   TOWN  36432.8      NO       NO  YES       NO         YES
#
#       mortgage  pep
#   151       NO  YES  ,
#   54618.8:      age   sex region   income married children car save_act current_act  \
#   152   63  MALE   TOWN  54618.8     YES       NO  NO      YES          NO
#
#       mortgage  pep
#   152      YES  YES  ,
#   24760.8:      age   sex      region   income married children car save_act current_act  \
#   153   33  MALE  INNER_CITY  24760.8     YES      YES  NO      YES         YES
#
#       mortgage  pep
#   153      YES  YES  ,
#   23356.1:      age   sex region   income married children  car save_act current_act  \
#   154   41  MALE  RURAL  23356.1      NO       NO  YES       NO          NO
#
#       mortgage pep
#   154       NO  NO  ,
#   8143.75:      age     sex    region   income married children car save_act current_act  \
#   155   20  FEMALE  SUBURBAN  8143.75     YES       NO  NO      YES         YES
#
#       mortgage  pep
#   155       NO  YES  ,
#   26462.5:      age   sex region   income married children  car save_act current_act  \
#   156   50  MALE   TOWN  26462.5     YES      YES  YES      YES         YES
#
#       mortgage pep
#   156       NO  NO  ,
#   20467.3:      age   sex region   income married children  car save_act current_act  \
#   157   24  MALE  RURAL  20467.3     YES       NO  YES      YES         YES
#
#       mortgage pep
#   157       NO  NO  ,
#   21506.2:      age     sex region   income married children car save_act current_act  \
#   158   60  FEMALE   TOWN  21506.2     YES      YES  NO       NO         YES
#
#       mortgage  pep
#   158       NO  YES  ,
#   15315.3:      age     sex region   income married children car save_act current_act  \
#   159   44  FEMALE   TOWN  15315.3     YES      YES  NO      YES         YES
#
#       mortgage  pep
#   159       NO  YES  ,
#   18875.7:      age   sex      region   income married children  car save_act  \
#   160   23  MALE  INNER_CITY  18875.7     YES       NO  YES      YES
#
#       current_act mortgage pep
#   160         YES       NO  NO  ,
#   12977.2:      age     sex      region   income married children car save_act  \
#   161   40  FEMALE  INNER_CITY  12977.2     YES      YES  NO       NO
#
#       current_act mortgage pep
#   161          NO       NO  NO  ,
#   20708.5:      age     sex region   income married children car save_act current_act  \
#   162   49  FEMALE   TOWN  20708.5      NO       NO  NO       NO         YES
#
#       mortgage pep
#   162       NO  NO  ,
#   7549.38:      age     sex region   income married children  car save_act current_act  \
#   163   21  FEMALE   TOWN  7549.38      NO      YES  YES       NO         YES
#
#       mortgage pep
#   163       NO  NO  ,
#   24904.0:      age     sex      region   income married children car save_act  \
#   164   40  FEMALE  INNER_CITY  24904.0     YES      YES  NO       NO
#
#       current_act mortgage pep
#   164          NO       NO  NO  ,
#   24071.8:      age   sex region   income married children car save_act current_act  \
#   165   26  MALE  RURAL  24071.8     YES      YES  NO       NO         YES
#
#       mortgage  pep
#   165      YES  YES  ,
#   9589.91:      age   sex region   income married children car save_act current_act  \
#   166   20  MALE   TOWN  9589.91      NO      YES  NO      YES         YES
#
#       mortgage pep
#   166      YES  NO  ,
#   8562.86:      age   sex      region   income married children car save_act current_act  \
#   167   24  MALE  INNER_CITY  8562.86      NO      YES  NO       NO          NO
#
#       mortgage pep
#   167      YES  NO  ,
#   26707.5:      age     sex region   income married children  car save_act current_act  \
#   168   37  FEMALE   TOWN  26707.5      NO      YES  YES      YES         YES
#
#       mortgage pep
#   168       NO  NO  ,
#   34020.5:      age   sex      region   income married children car save_act current_act  \
#   169   56  MALE  INNER_CITY  34020.5     YES      YES  NO       NO         YES
#
#       mortgage pep
#   169       NO  NO  ,
#   49175.7:      age   sex      region   income married children  car save_act  \
#   170   52  MALE  INNER_CITY  49175.7     YES      YES  YES      YES
#
#       current_act mortgage pep
#   170         YES       NO  NO  ,
#   19726.3:      age   sex      region   income married children car save_act current_act  \
#   171   22  MALE  INNER_CITY  19726.3     YES       NO  NO       NO         YES
#
#       mortgage pep
#   171       NO  NO  ,
#   24346.6:      age   sex      region   income married children  car save_act  \
#   172   35  MALE  INNER_CITY  24346.6     YES       NO  YES      YES
#
#       current_act mortgage pep
#   172         YES       NO  NO  ,
#   26999.4:      age   sex region   income married children  car save_act current_act  \
#   173   34  MALE  RURAL  26999.4     YES      YES  YES      YES         YES
#
#       mortgage  pep
#   173       NO  YES  ,
#   41558.1:      age     sex region   income married children car save_act current_act  \
#   174   67  FEMALE   TOWN  41558.1     YES       NO  NO      YES         YES
#
#       mortgage  pep
#   174       NO  YES  ,
#   56340.3:      age     sex      region   income married children car save_act  \
#   175   58  FEMALE  INNER_CITY  56340.3      NO      YES  NO      YES
#
#       current_act mortgage  pep
#   175         YES       NO  YES  ,
#   37558.5:      age   sex region   income married children  car save_act current_act  \
#   176   40  MALE   TOWN  37558.5     YES      YES  YES      YES         YES
#
#       mortgage pep
#   176       NO  NO  ,
#   30099.3:      age     sex      region   income married children  car save_act  \
#   177   41  FEMALE  INNER_CITY  30099.3     YES      YES  YES      YES
#
#       current_act mortgage  pep
#   177         YES      YES  YES  ,
#   15254.8:      age   sex      region   income married children car save_act current_act  \
#   178   43  MALE  INNER_CITY  15254.8     YES      YES  NO       NO          NO
#
#       mortgage  pep
#   178       NO  YES  ,
#   36086.1:      age   sex      region   income married children car save_act current_act  \
#   179   63  MALE  INNER_CITY  36086.1     YES       NO  NO       NO         YES
#
#       mortgage  pep
#   179       NO  YES  ,
#   17655.0:      age     sex      region   income married children car save_act  \
#   180   22  FEMALE  INNER_CITY  17655.0     YES      YES  NO      YES
#
#       current_act mortgage  pep
#   180         YES      YES  YES  ,
#   56658.9:      age   sex region   income married children car save_act current_act  \
#   181   60  MALE  RURAL  56658.9      NO      YES  NO      YES         YES
#
#       mortgage  pep
#   181       NO  YES  ,
#   37706.5:      age     sex      region   income married children  car save_act  \
#   182   65  FEMALE  INNER_CITY  37706.5      NO      YES  YES      YES
#
#       current_act mortgage pep
#   182         YES      YES  NO  ,
#   18516.0:      age     sex      region   income married children  car save_act  \
#   183   48  FEMALE  INNER_CITY  18516.0     YES       NO  YES      YES
#
#       current_act mortgage pep
#   183         YES      YES  NO  ,
#   29622.0:      age     sex      region   income married children  car save_act  \
#   184   38  FEMALE  INNER_CITY  29622.0      NO      YES  YES      YES
#
#       current_act mortgage pep
#   184          NO      YES  NO  ,
#   32669.9:      age   sex region   income married children  car save_act current_act  \
#   185   49  MALE  RURAL  32669.9     YES      YES  YES      YES         YES
#
#       mortgage  pep
#   185      YES  YES  ,
#   18275.5:      age     sex      region   income married children car save_act  \
#   186   20  FEMALE  INNER_CITY  18275.5     YES      YES  NO       NO
#
#       current_act mortgage  pep
#   186          NO      YES  YES  ,
#   34410.0:      age     sex region   income married children car save_act current_act  \
#   187   48  FEMALE   TOWN  34410.0     YES      YES  NO       NO         YES
#
#       mortgage  pep
#   187       NO  YES  ,
#   34866.9:      age   sex      region   income married children  car save_act  \
#   188   38  MALE  INNER_CITY  34866.9     YES       NO  YES       NO
#
#       current_act mortgage pep
#   188         YES      YES  NO  ,
#   21796.6:      age     sex      region   income married children car save_act  \
#   189   41  FEMALE  INNER_CITY  21796.6     YES      YES  NO       NO
#
#       current_act mortgage pep
#   189         YES       NO  NO  ,
#   63130.1:      age     sex    region   income married children  car save_act  \
#   190   67  FEMALE  SUBURBAN  63130.1     YES       NO  YES      YES
#
#       current_act mortgage  pep
#   190         YES       NO  YES  ,
#   14996.4:      age   sex      region   income married children  car save_act  \
#   191   39  MALE  INNER_CITY  14996.4     YES      YES  YES      YES
#
#       current_act mortgage pep
#   191          NO       NO  NO  ,
#   49024.9:      age     sex region   income married children car save_act current_act  \
#   192   64  FEMALE  RURAL  49024.9     YES       NO  NO      YES         YES
#
#       mortgage  pep
#   192       NO  YES  ,
#   16249.8:      age   sex      region   income married children  car save_act  \
#   193   41  MALE  INNER_CITY  16249.8     YES      YES  YES       NO
#
#       current_act mortgage  pep
#   193         YES      YES  YES  ,
#   36192.1:      age   sex    region   income married children  car save_act current_act  \
#   194   55  MALE  SUBURBAN  36192.1     YES       NO  YES       NO         YES
#
#       mortgage  pep
#   194       NO  YES  ,
#   17839.9:      age   sex      region   income married children car save_act current_act  \
#   195   52  MALE  INNER_CITY  17839.9     YES      YES  NO      YES          NO
#
#       mortgage  pep
#   195      YES  YES  ,
#   18802.4:      age     sex      region   income married children car save_act  \
#   196   30  FEMALE  INNER_CITY  18802.4      NO      YES  NO       NO
#
#       current_act mortgage  pep
#   196         YES      YES  YES  ,
#   48720.3:      age   sex      region   income married children  car save_act  \
#   197   52  MALE  INNER_CITY  48720.3     YES       NO  YES      YES
#
#       current_act mortgage  pep
#   197         YES       NO  YES  ,
#   14585.9:      age   sex      region   income married children car save_act current_act  \
#   198   26  MALE  INNER_CITY  14585.9      NO       NO  NO       NO         YES
#
#       mortgage pep
#   198      YES  NO  ,
#   20819.0:      age     sex      region   income married children car save_act  \
#   199   26  FEMALE  INNER_CITY  20819.0     YES      YES  NO      YES
#
#       current_act mortgage  pep
#   199         YES       NO  YES  ,
#   26077.8:      age   sex region   income married children  car save_act current_act  \
#   200   46  MALE   TOWN  26077.8     YES      YES  YES      YES         YES
#
#       mortgage  pep
#   200       NO  YES  ,
#   41627.1:      age     sex region   income married children car save_act current_act  \
#   201   46  FEMALE   TOWN  41627.1     YES      YES  NO      YES         YES
#
#       mortgage pep
#   201      YES  NO  ,
#   16977.3:      age   sex      region   income married children car save_act current_act  \
#   202   52  MALE  INNER_CITY  16977.3     YES      YES  NO       NO         YES
#
#       mortgage pep
#   202       NO  NO  ,
#   19012.8:      age   sex      region   income married children  car save_act  \
#   203   37  MALE  INNER_CITY  19012.8      NO       NO  YES       NO
#
#       current_act mortgage pep
#   203         YES       NO  NO  ,
#   12764.8:      age   sex      region   income married children car save_act current_act  \
#   204   22  MALE  INNER_CITY  12764.8     YES      YES  NO      YES         YES
#
#       mortgage  pep
#   204      YES  YES  ,
#   14388.6:      age   sex      region   income married children  car save_act  \
#   205   18  MALE  INNER_CITY  14388.6      NO      YES  YES       NO
#
#       current_act mortgage  pep
#   205         YES      YES  YES  ,
#   59409.1:      age   sex      region   income married children  car save_act  \
#   206   63  MALE  INNER_CITY  59409.1      NO      YES  YES      YES
#
#       current_act mortgage  pep
#   206         YES       NO  YES  ,
#   14960.2:      age     sex      region   income married children car save_act  \
#   207   25  FEMALE  INNER_CITY  14960.2     YES      YES  NO      YES
#
#       current_act mortgage pep
#   207         YES      YES  NO  ,
#   39666.6:      age   sex      region   income married children  car save_act  \
#   208   67  MALE  INNER_CITY  39666.6     YES      YES  YES      YES
#
#       current_act mortgage pep
#   208         YES       NO  NO  ,
#   20771.9:      age   sex      region   income married children car save_act current_act  \
#   209   27  MALE  INNER_CITY  20771.9      NO      YES  NO      YES          NO
#
#       mortgage  pep
#   209       NO  YES  ,
#   24474.1:      age   sex      region   income married children  car save_act  \
#   210   61  MALE  INNER_CITY  24474.1      NO      YES  YES       NO
#
#       current_act mortgage  pep
#   210          NO       NO  YES  ,
#   33123.7:      age   sex region   income married children  car save_act current_act  \
#   211   58  MALE   TOWN  33123.7     YES      YES  YES      YES         YES
#
#       mortgage  pep
#   211       NO  YES  ,
#   14433.4:      age   sex      region   income married children  car save_act  \
#   212   22  MALE  INNER_CITY  14433.4     YES      YES  YES      YES
#
#       current_act mortgage  pep
#   212         YES       NO  YES  ,
#   13175.5:      age   sex region   income married children car save_act current_act  \
#   213   28  MALE   TOWN  13175.5      NO      YES  NO       NO         YES
#
#       mortgage  pep
#   213       NO  YES  ,
#   9824.37:      age   sex      region   income married children car save_act current_act  \
#   214   23  MALE  INNER_CITY  9824.37     YES      YES  NO      YES         YES
#
#       mortgage pep
#   214       NO  NO  ,
#   17610.3:      age   sex    region   income married children car save_act current_act  \
#   215   27  MALE  SUBURBAN  17610.3     YES      YES  NO      YES         YES
#
#       mortgage pep
#   215       NO  NO  ,
#   15156.2:      age     sex    region   income married children  car save_act  \
#   216   27  FEMALE  SUBURBAN  15156.2     YES      YES  YES       NO
#
#       current_act mortgage pep
#   216         YES       NO  NO  ,
#   31774.1:      age     sex      region   income married children  car save_act  \
#   217   40  FEMALE  INNER_CITY  31774.1     YES       NO  YES      YES
#
#       current_act mortgage pep
#   217         YES      YES  NO  ,
#   31693.5:      age   sex region   income married children  car save_act current_act  \
#   218   39  MALE   TOWN  31693.5      NO      YES  YES      YES          NO
#
#       mortgage  pep
#   218       NO  YES  ,
#   28598.7:      age     sex      region   income married children  car save_act  \
#   219   35  FEMALE  INNER_CITY  28598.7     YES      YES  YES      YES
#
#       current_act mortgage pep
# ...
#   527   21  FEMALE   TOWN  10672.0      NO      YES  NO      YES         YES
#
#       mortgage pep
#   527      YES  NO  ,
#   25830.5:      age     sex      region   income married children car save_act  \
#   528   30  FEMALE  INNER_CITY  25830.5     YES       NO  NO       NO
#
#       current_act mortgage pep
#   528         YES       NO  NO  ,
#   43499.5:      age   sex region   income married children  car save_act current_act  \
#   529   55  MALE  RURAL  43499.5     YES      YES  YES      YES         YES
#
#       mortgage pep
#   529       NO  NO  ,
#   59175.1:      age   sex    region   income married children car save_act current_act  \
#   530   64  MALE  SUBURBAN  59175.1     YES      YES  NO      YES         YES
#
#       mortgage  pep
#   530       NO  YES  ,
#   27642.9:      age     sex      region   income married children  car save_act  \
#   531   36  FEMALE  INNER_CITY  27642.9      NO      YES  YES       NO
#
#       current_act mortgage  pep
#   531          NO       NO  YES  ,
#   30067.5:      age   sex      region   income married children car save_act current_act  \
#   532   59  MALE  INNER_CITY  30067.5      NO      YES  NO      YES         YES
#
#       mortgage  pep
#   532       NO  YES  ,
#   29714.4:      age   sex      region   income married children  car save_act  \
#   533   60  MALE  INNER_CITY  29714.4     YES      YES  YES       NO
#
#       current_act mortgage  pep
#   533         YES      YES  YES  ,
#   13950.4:      age     sex region   income married children  car save_act current_act  \
#   534   27  FEMALE   TOWN  13950.4      NO      YES  YES      YES         YES
#
#       mortgage pep
#   534      YES  NO  ,
#   10072.6:      age   sex      region   income married children car save_act current_act  \
#   535   29  MALE  INNER_CITY  10072.6     YES      YES  NO       NO         YES
#
#       mortgage pep
#   535       NO  NO  ,
#   37850.6:      age     sex      region   income married children car save_act  \
#   536   53  FEMALE  INNER_CITY  37850.6      NO      YES  NO      YES
#
#       current_act mortgage  pep
#   536         YES       NO  YES  ,
#   57176.4:      age     sex region   income married children car save_act current_act  \
#   537   61  FEMALE  RURAL  57176.4      NO       NO  NO      YES         YES
#
#       mortgage  pep
#   537       NO  YES  ,
#   38784.0:      age     sex      region   income married children car save_act  \
#   538   43  FEMALE  INNER_CITY  38784.0     YES      YES  NO      YES
#
#       current_act mortgage pep
#   538         YES       NO  NO  ,
#   10191.8:      age   sex      region   income married children car save_act current_act  \
#   539   19  MALE  INNER_CITY  10191.8     YES      YES  NO      YES         YES
#
#       mortgage  pep
#   539      YES  YES  ,
#   21821.4:      age     sex      region   income married children  car save_act  \
#   540   48  FEMALE  INNER_CITY  21821.4     YES      YES  YES      YES
#
#       current_act mortgage  pep
#   540          NO      YES  YES  ,
#   37389.0:      age   sex region   income married children car save_act current_act  \
#   541   39  MALE  RURAL  37389.0     YES       NO  NO      YES         YES
#
#       mortgage  pep
#   541       NO  YES  ,
#   14627.9:      age   sex      region   income married children  car save_act  \
#   542   32  MALE  INNER_CITY  14627.9     YES       NO  YES      YES
#
#       current_act mortgage pep
#   542         YES       NO  NO  ,
#   48770.5:      age   sex    region   income married children  car save_act current_act  \
#   543   63  MALE  SUBURBAN  48770.5     YES      YES  YES      YES          NO
#
#       mortgage  pep
#   543      YES  YES  ,
#   21096.2:      age   sex region   income married children  car save_act current_act  \
#   544   46  MALE  RURAL  21096.2     YES      YES  YES      YES         YES
#
#       mortgage  pep
#   544       NO  YES  ,
#   36256.9:      age   sex      region   income married children car save_act current_act  \
#   545   40  MALE  INNER_CITY  36256.9      NO      YES  NO       NO         YES
#
#       mortgage  pep
#   545      YES  YES  ,
#   15281.8:      age     sex      region   income married children  car save_act  \
#   546   27  FEMALE  INNER_CITY  15281.8      NO      YES  YES       NO
#
#       current_act mortgage  pep
#   546          NO      YES  YES  ,
#   9316.98:      age   sex    region   income married children  car save_act current_act  \
#   547   22  MALE  SUBURBAN  9316.98     YES       NO  YES      YES         YES
#
#       mortgage pep
#   547       NO  NO  ,
#   20736.2:      age   sex region   income married children  car save_act current_act  \
#   548   42  MALE  RURAL  20736.2     YES      YES  YES      YES         YES
#
#       mortgage  pep
#   548       NO  YES  ,
#   52662.5:      age     sex region   income married children  car save_act current_act  \
#   549   58  FEMALE   TOWN  52662.5     YES      YES  YES      YES         YES
#
#       mortgage  pep
#   549      YES  YES  ,
#   8020.19:      age     sex      region   income married children  car save_act  \
#   550   23  FEMALE  INNER_CITY  8020.19     YES      YES  YES       NO
#
#       current_act mortgage pep
#   550         YES       NO  NO  ,
#   32245.4:      age   sex    region   income married children car save_act current_act  \
#   551   58  MALE  SUBURBAN  32245.4     YES       NO  NO       NO          NO
#
#       mortgage pep
#   551       NO  NO  ,
#   41107.2:      age   sex      region   income married children  car save_act  \
#   552   45  MALE  INNER_CITY  41107.2     YES       NO  YES      YES
#
#       current_act mortgage pep
#   552         YES       NO  NO  ,
#   39358.3:      age     sex    region   income married children  car save_act  \
#   553   49  FEMALE  SUBURBAN  39358.3     YES      YES  YES       NO
#
#       current_act mortgage pep
#   553          NO      YES  NO  ,
#   36095.9:      age     sex      region   income married children  car save_act  \
#   554   67  FEMALE  INNER_CITY  36095.9     YES       NO  YES      YES
#
#       current_act mortgage pep
#   554         YES       NO  NO  ,
#   7723.93:      age     sex region   income married children  car save_act current_act  \
#   555   20  FEMALE   TOWN  7723.93     YES       NO  YES      YES         YES
#
#       mortgage pep
#   555       NO  NO  ,
#   18565.8:      age     sex region   income married children  car save_act current_act  \
#   556   43  FEMALE  RURAL  18565.8     YES      YES  YES      YES         YES
#
#       mortgage  pep
#   556      YES  YES  ,
#   25132.9:      age   sex region   income married children car save_act current_act  \
#   557   41  MALE  RURAL  25132.9     YES      YES  NO       NO         YES
#
#       mortgage pep
#   557       NO  NO  ,
#   31290.6:      age     sex    region   income married children car save_act current_act  \
#   558   38  FEMALE  SUBURBAN  31290.6     YES      YES  NO      YES         YES
#
#       mortgage pep
#   558       NO  NO  ,
#   24858.4:      age     sex    region   income married children car save_act current_act  \
#   559   67  FEMALE  SUBURBAN  24858.4     YES      YES  NO       NO         YES
#
#       mortgage  pep
#   559      YES  YES  ,
#   16398.8:      age   sex      region   income married children car save_act current_act  \
#   560   40  MALE  INNER_CITY  16398.8      NO      YES  NO      YES         YES
#
#       mortgage  pep
#   560       NO  YES  ,
#   23287.9:      age     sex    region   income married children car save_act current_act  \
#   561   25  FEMALE  SUBURBAN  23287.9      NO      YES  NO       NO         YES
#
#       mortgage  pep
#   561      YES  YES  ,
#   50897.6:      age     sex region   income married children car save_act current_act  \
#   562   57  FEMALE  RURAL  50897.6     YES      YES  NO      YES         YES
#
#       mortgage pep
#   562       NO  NO  ,
#   22446.5:      age     sex      region   income married children car save_act  \
#   563   32  FEMALE  INNER_CITY  22446.5      NO      YES  NO       NO
#
#       current_act mortgage  pep
#   563         YES      YES  YES  ,
#   23092.1:      age   sex    region   income married children  car save_act current_act  \
#   564   44  MALE  SUBURBAN  23092.1     YES      YES  YES       NO         YES
#
#       mortgage  pep
#   564      YES  YES  ,
#   24867.6:      age   sex region   income married children  car save_act current_act  \
#   565   30  MALE   TOWN  24867.6     YES      YES  YES      YES          NO
#
#       mortgage pep
#   565       NO  NO  ,
#   22234.7:      age   sex region   income married children car save_act current_act  \
#   566   43  MALE   TOWN  22234.7     YES      YES  NO       NO         YES
#
#       mortgage pep
#   566      YES  NO  ,
#   17371.1:      age     sex      region   income married children  car save_act  \
#   567   19  FEMALE  INNER_CITY  17371.1     YES       NO  YES      YES
#
#       current_act mortgage pep
#   567         YES       NO  NO  ,
#   29574.0:      age     sex region   income married children  car save_act current_act  \
#   568   37  FEMALE   TOWN  29574.0     YES      YES  YES      YES         YES
#
#       mortgage pep
#   568       NO  NO  ,
#   17944.2:      age   sex      region   income married children  car save_act  \
#   569   49  MALE  INNER_CITY  17944.2      NO      YES  YES      YES
#
#       current_act mortgage  pep
#   569         YES      YES  YES  ,
#   33665.5:      age     sex region   income married children  car save_act current_act  \
#   570   49  FEMALE  RURAL  33665.5      NO       NO  YES       NO         YES
#
#       mortgage pep
#   570       NO  NO  ,
#   36166.2:      age   sex      region   income married children car save_act current_act  \
#   571   40  MALE  INNER_CITY  36166.2     YES      YES  NO       NO          NO
#
#       mortgage pep
#   571       NO  NO  ,
#   27712.9:      age     sex    region   income married children car save_act current_act  \
#   572   33  FEMALE  SUBURBAN  27712.9      NO       NO  NO      YES         YES
#
#       mortgage  pep
#   572       NO  YES  ,
#   22400.7:      age   sex region   income married children  car save_act current_act  \
#   573   39  MALE   TOWN  22400.7     YES       NO  YES      YES         YES
#
#       mortgage pep
#   573       NO  NO  ,
#   28469.9:      age     sex      region   income married children  car save_act  \
#   574   43  FEMALE  INNER_CITY  28469.9     YES      YES  YES      YES
#
#       current_act mortgage pep
#   574         YES       NO  NO  ,
#   30488.0:      age   sex region   income married children car save_act current_act  \
#   575   37  MALE   TOWN  30488.0     YES      YES  NO      YES         YES
#
#       mortgage pep
#   575      YES  NO  ,
#   19160.3:      age     sex region   income married children  car save_act current_act  \
#   576   24  FEMALE   TOWN  19160.3     YES      YES  YES      YES         YES
#
#       mortgage  pep
#   576       NO  YES  ,
#   45342.5:      age   sex region   income married children  car save_act current_act  \
#   577   62  MALE   TOWN  45342.5     YES      YES  YES      YES          NO
#
#       mortgage  pep
#   577       NO  YES  ,
#   6294.21:      age   sex      region   income married children car save_act current_act  \
#   578   18  MALE  INNER_CITY  6294.21      NO      YES  NO      YES         YES
#
#       mortgage pep
#   578      YES  NO  ,
#   25127.7:      age     sex region   income married children  car save_act current_act  \
#   579   47  FEMALE   TOWN  25127.7     YES      YES  YES       NO          NO
#
#       mortgage pep
#   579       NO  NO  ,
#   51879.3:      age   sex    region   income married children  car save_act current_act  \
#   580   63  MALE  SUBURBAN  51879.3     YES       NO  YES      YES          NO
#
#       mortgage  pep
#   580      YES  YES  ,
#   12644.9:      age   sex region   income married children  car save_act current_act  \
#   581   20  MALE   TOWN  12644.9     YES       NO  YES       NO         YES
#
#       mortgage pep
#   581      YES  NO  ,
#   21984.4:      age     sex region   income married children car save_act current_act  \
#   582   46  FEMALE   TOWN  21984.4      NO       NO  NO      YES          NO
#
#       mortgage pep
#   582       NO  NO  ,
#   29093.1:      age     sex region   income married children  car save_act current_act  \
#   583   47  FEMALE  RURAL  29093.1      NO       NO  YES      YES         YES
#
#       mortgage pep
#   583       NO  NO  ,
#   23528.4:      age   sex region   income married children car save_act current_act  \
#   584   33  MALE   TOWN  23528.4     YES      YES  NO      YES         YES
#
#       mortgage  pep
#   584      YES  YES  ,
#   9516.91:      age   sex region   income married children  car save_act current_act  \
#   585   20  MALE   TOWN  9516.91      NO       NO  YES      YES         YES
#
#       mortgage pep
#   585       NO  NO  ,
#   18364.9:      age   sex      region   income married children car save_act current_act  \
#   586   20  MALE  INNER_CITY  18364.9     YES      YES  NO       NO         YES
#
#       mortgage  pep
#   586       NO  YES  ,
#   31273.8:      age     sex region   income married children  car save_act current_act  \
#   587   43  FEMALE   TOWN  31273.8      NO      YES  YES      YES          NO
#
#       mortgage  pep
#   587       NO  YES  ,
#   49673.6:      age   sex region   income married children car save_act current_act  \
#   588   58  MALE  RURAL  49673.6     YES      YES  NO      YES         YES
#
#       mortgage pep
#   588       NO  NO  ,
#   12623.4:      age   sex    region   income married children  car save_act current_act  \
#   589   29  MALE  SUBURBAN  12623.4     YES      YES  YES      YES         YES
#
#       mortgage pep
#   589       NO  NO  ,
#   23818.6:      age   sex      region   income married children car save_act current_act  \
#   590   25  MALE  INNER_CITY  23818.6     YES      YES  NO       NO          NO
#
#       mortgage pep
#   590       NO  NO  ,
#   31473.9:      age     sex      region   income married children car save_act  \
#   591   40  FEMALE  INNER_CITY  31473.9      NO       NO  NO      YES
#
#       current_act mortgage  pep
#   591         YES      YES  YES  ,
#   20268.0:      age   sex region   income married children car save_act current_act  \
#   592   48  MALE   TOWN  20268.0     YES      YES  NO      YES         YES
#
#       mortgage pep
#   592       NO  NO  ,
#   51417.0:      age   sex    region   income married children car save_act current_act  \
#   593   65  MALE  SUBURBAN  51417.0     YES       NO  NO      YES         YES
#
#       mortgage  pep
#   593       NO  YES  ,
#   30971.8:      age     sex region   income married children  car save_act current_act  \
#   594   59  FEMALE  RURAL  30971.8     YES       NO  YES      YES         YES
#
#       mortgage pep
#   594      YES  NO  ,
#   47025.0:      age     sex      region   income married children  car save_act  \
#   595   61  FEMALE  INNER_CITY  47025.0      NO       NO  YES      YES
#
#       current_act mortgage pep
#   595         YES      YES  NO  ,
#   9672.25:      age     sex      region   income married children  car save_act  \
#   596   30  FEMALE  INNER_CITY  9672.25     YES      YES  YES      YES
#
#       current_act mortgage pep
#   596         YES       NO  NO  ,
#   15976.3:      age     sex region   income married children  car save_act current_act  \
#   597   31  FEMALE   TOWN  15976.3     YES      YES  YES      YES          NO
#
#       mortgage  pep
#   597       NO  YES  ,
#   14711.8:      age   sex      region   income married children car save_act current_act  \
#   598   29  MALE  INNER_CITY  14711.8     YES      YES  NO      YES          NO
#
#       mortgage pep
#   598      YES  NO  ,
#   26671.6:      age   sex region   income married children  car save_act current_act  \
#   599   38  MALE   TOWN  26671.6      NO      YES  YES       NO         YES
#
#       mortgage  pep
#   599      YES  YES  },
#  'income')

# %% [markdown]
# # 定义CART分类树的构建过程

# %%
class CartTree:
    class Node:
        def __init__(self,name):
            self.name,self.connections=name,{}
        def connect(self,label,node):
            self.connections[label]=node
    def __init__(self,df,label):
        self.df,self.columns,self.label,self.root=df,df.columns,label,self.Node('Root')
    def construct(self,parent_node,parent_con_label,df,columns):
        min_gini,min_split_df,best_col=choose_best_col(df[columns],self.label)
        if not best_col:
            node=self.Node(df[self.label].iloc[0])
            parent_node.connect(parent_con_label,node)
        else:
            node=self.Node(best_col)
            parent_node.connect(parent_con_label,node)
            new_columns=[c for c in columns if c!=best_col]
            for split_v,split_data in min_split_df.items():
                self.construct(node,split_v,split_data,new_columns)
    def construct_tree(self):
        self.construct(self.root,"Root",self.df,self.columns)
    def print_tree(self,root,tabs):
        print(f"{tabs}({root.name})")
        for label ,node in root.connections.items():
            print(f"{tabs}\t| <{label}>")
            self.print_tree(node,tabs+"\t\t|")

tree=CartTree(df,"pep")
tree.construct_tree()
tree.print_tree(tree.root,"| ")
# Out:
# | (Root)
# | 	| <Root>
# | 		|(income)
# | 		|	| <17546.0>
# | 		|		|(age)
# | 		|		|	| <48>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <30085.1>
# | 		|		|(age)
# | 		|		|	| <40>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <16575.4>
# | 		|		|(age)
# | 		|		|	| <51>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <20375.4>
# | 		|		|(age)
# | 		|		|	| <23>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <50576.3>
# | 		|		|(age)
# | 		|		|	| <57>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <RURAL>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <37869.6>
# | 		|		|(age)
# | 		|		|	| <57>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <8877.07>
# | 		|		|(age)
# | 		|		|	| <22>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <RURAL>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <24946.6>
# | 		|		|(age)
# | 		|		|	| <58>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <25304.3>
# | 		|		|(age)
# | 		|		|	| <37>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <SUBURBAN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <24212.1>
# | 		|		|(age)
# | 		|		|	| <54>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <59803.9>
# | 		|		|(age)
# | 		|		|	| <66>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <26658.8>
# | 		|		|(age)
# | 		|		|	| <52>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <15735.8>
# | 		|		|(age)
# | 		|		|	| <44>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <55204.7>
# | 		|		|(age)
# | 		|		|	| <66>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <19474.6>
# | 		|		|(age)
# | 		|		|	| <36>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <RURAL>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <22342.1>
# | 		|		|(age)
# | 		|		|	| <38>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <17729.8>
# | 		|		|(age)
# | 		|		|	| <37>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <41016.0>
# | 		|		|(age)
# | 		|		|	| <46>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <SUBURBAN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <26909.2>
# | 		|		|(age)
# | 		|		|	| <62>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <22522.8>
# | 		|		|(age)
# | 		|		|	| <31>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <57880.7>
# | 		|		|(age)
# | 		|		|	| <61>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <16497.3>
# | 		|		|(age)
# | 		|		|	| <50>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <38446.6>
# | 		|		|(age)
# | 		|		|	| <54>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <15538.8>
# | 		|		|(age)
# | 		|		|	| <27>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <12640.3>
# | 		|		|(age)
# | 		|		|	| <22>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <41034.0>
# | 		|		|(age)
# | 		|		|	| <56>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <20809.7>
# | 		|		|(age)
# | 		|		|	| <45>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <20114.0>
# | 		|		|(age)
# | 		|		|	| <39>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <29359.1>
# | 		|		|(age)
# | 		|		|	| <39>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <24270.1>
# | 		|		|(age)
# | 		|		|	| <61>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <RURAL>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <22942.9>
# | 		|		|(age)
# | 		|		|	| <61>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <RURAL>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <16325.8>
# | 		|		|(age)
# | 		|		|	| <20>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <23443.2>
# | 		|		|(age)
# | 		|		|	| <45>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <SUBURBAN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <29921.3>
# | 		|		|(age)
# | 		|		|	| <33>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <37521.9>
# | 		|		|(age)
# | 		|		|	| <43>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <SUBURBAN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <19868.0>
# | 		|		|(age)
# | 		|		|	| <27>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <10953.0>
# | 		|		|(age)
# | 		|		|	| <19>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <RURAL>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <13381.0>
# | 		|		|(age)
# | 		|		|	| <36>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <RURAL>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <18504.3>
# | 		|		|(age)
# | 		|		|	| <43>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <25391.5>
# | 		|		|(age)
# | 		|		|	| <66>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <SUBURBAN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <26774.2>
# | 		|		|(age)
# | 		|		|	| <55>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <26952.6>
# | 		|		|(age)
# | 		|		|	| <47>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <55716.5>
# | 		|		|(age)
# | 		|		|	| <67>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <27571.5>
# | 		|		|(age)
# | 		|		|	| <32>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <13740.0>
# | 		|		|(age)
# | 		|		|	| <20>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <52670.6>
# | 		|		|(age)
# | 		|		|	| <64>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <13283.9>
# | 		|		|(age)
# | 		|		|	| <50>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <13106.6>
# | 		|		|(age)
# | 		|		|	| <29>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <39547.8>
# | 		|		|(age)
# | 		|		|	| <52>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <17867.3>
# | 		|		|(age)
# | 		|		|	| <47>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <RURAL>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <14309.7>
# | 		|		|(age)
# | 		|		|	| <24>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <23894.8>
# | 		|		|(age)
# | 		|		|	| <36>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <16259.7>
# | 		|		|(age)
# | 		|		|	| <43>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <29794.1>
# | 		|		|(age)
# | 		|		|	| <48>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <SUBURBAN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <56842.5>
# | 		|		|(age)
# | 		|		|	| <63>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <47835.8>
# | 		|		|(age)
# | 		|		|	| <52>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <RURAL>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <24977.5>
# | 		|		|(age)
# | 		|		|	| <58>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <23124.9>
# | 		|		|(age)
# | 		|		|	| <28>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <15143.8>
# | 		|		|(age)
# | 		|		|	| <29>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <25334.3>
# | 		|		|(age)
# | 		|		|	| <34>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <24763.3>
# | 		|		|(age)
# | 		|		|	| <42>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <36589.0>
# | 		|		|(age)
# | 		|		|	| <65>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <27022.6>
# | 		|		|(age)
# | 		|		|	| <47>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <11700.4>
# | 		|		|(age)
# | 		|		|	| <20>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <5014.21>
# | 		|		|(age)
# | 		|		|	| <21>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <17390.1>
# | 		|		|(age)
# | 		|		|	| <42>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <10861.0>
# | 		|		|(age)
# | 		|		|	| <19>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <34892.9>
# | 		|		|(age)
# | 		|		|	| <41>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <19403.1>
# | 		|		|(age)
# | 		|		|	| <30>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <10441.9>
# | 		|		|(age)
# | 		|		|	| <31>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <RURAL>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <14064.9>
# | 		|		|(age)
# | 		|		|	| <25>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <8062.73>
# | 		|		|(age)
# | 		|		|	| <21>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <31982.0>
# | 		|		|(age)
# | 		|		|	| <36>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <23197.5>
# | 		|		|(age)
# | 		|		|	| <58>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <52674.0>
# | 		|		|(age)
# | 		|		|	| <64>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <35610.5>
# | 		|		|(age)
# | 		|		|	| <59>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <RURAL>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <26948.0>
# | 		|		|(age)
# | 		|		|	| <45>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <49456.7>
# | 		|		|(age)
# | 		|		|	| <61>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <14724.5>
# | 		|		|(age)
# | 		|		|	| <30>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <34524.9>
# | 		|		|(age)
# | 		|		|	| <58>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <22052.1>
# | 		|		|(age)
# | 		|		|	| <50>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <27808.1>
# | 		|		|(age)
# | 		|		|	| <30>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# ...
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <22400.7>
# | 		|		|(age)
# | 		|		|	| <39>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <28469.9>
# | 		|		|(age)
# | 		|		|	| <43>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <30488.0>
# | 		|		|(age)
# | 		|		|	| <37>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <19160.3>
# | 		|		|(age)
# | 		|		|	| <24>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <45342.5>
# | 		|		|(age)
# | 		|		|	| <62>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <6294.21>
# | 		|		|(age)
# | 		|		|	| <18>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <25127.7>
# | 		|		|(age)
# | 		|		|	| <47>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <51879.3>
# | 		|		|(age)
# | 		|		|	| <63>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <SUBURBAN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <12644.9>
# | 		|		|(age)
# | 		|		|	| <20>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <21984.4>
# | 		|		|(age)
# | 		|		|	| <46>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <29093.1>
# | 		|		|(age)
# | 		|		|	| <47>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <RURAL>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <23528.4>
# | 		|		|(age)
# | 		|		|	| <33>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <9516.91>
# | 		|		|(age)
# | 		|		|	| <20>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <18364.9>
# | 		|		|(age)
# | 		|		|	| <20>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <31273.8>
# | 		|		|(age)
# | 		|		|	| <43>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <49673.6>
# | 		|		|(age)
# | 		|		|	| <58>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <RURAL>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <12623.4>
# | 		|		|(age)
# | 		|		|	| <29>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <SUBURBAN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <23818.6>
# | 		|		|(age)
# | 		|		|	| <25>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <31473.9>
# | 		|		|(age)
# | 		|		|	| <40>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <20268.0>
# | 		|		|(age)
# | 		|		|	| <48>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <51417.0>
# | 		|		|(age)
# | 		|		|	| <65>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <SUBURBAN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <30971.8>
# | 		|		|(age)
# | 		|		|	| <59>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <RURAL>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <47025.0>
# | 		|		|(age)
# | 		|		|	| <61>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <9672.25>
# | 		|		|(age)
# | 		|		|	| <30>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <15976.3>
# | 		|		|(age)
# | 		|		|	| <31>
# | 		|		|		|(sex)
# | 		|		|		|	| <FEMALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
# | 		|	| <14711.8>
# | 		|		|(age)
# | 		|		|	| <29>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <INNER_CITY>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(NO)
# | 		|	| <26671.6>
# | 		|		|(age)
# | 		|		|	| <38>
# | 		|		|		|(sex)
# | 		|		|		|	| <MALE>
# | 		|		|		|		|(region)
# | 		|		|		|		|	| <TOWN>
# | 		|		|		|		|		|(married)
# | 		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|(children)
# | 		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|(car)
# | 		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|(save_act)
# | 		|		|		|		|		|		|		|		|	| <NO>
# | 		|		|		|		|		|		|		|		|		|(current_act)
# | 		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|(mortgage)
# | 		|		|		|		|		|		|		|		|		|		|	| <YES>
# | 		|		|		|		|		|		|		|		|		|		|		|(YES)
